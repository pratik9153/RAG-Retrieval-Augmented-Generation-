# %% [markdown]
# ## Data Parsing with Docx

# %%
from langchain_community.document_loaders import (
    Docx2txtLoader,
    UnstructuredWordDocumentLoader,
)

# %% [markdown]
# # Method 1 - Docx2txtLoader

# %%
print("Docx2txtLoader")

try:
    docx_loader = Docx2txtLoader("data/docx/ml.docx")
    docs = docx_loader.load()

    print(f"Loaded : {len(docs)} documents")
    print(f"content preview : {docs[0].page_content[:100]}")
    print(f"Metadata :{docs[0].metadata}")


except Exception as e :
    print(f"Error {e}")
# Out:
# Docx2txtLoader
# Loaded : 1 documents
# content preview : Supervised Learning
#
#
#
# • DOMAIN : Automobiles
#
#
#
# CONTEXT :
#
# There is a huge demand for used cars in
# Metadata :{'source': 'data/docx/ml.docx'}

# %% [markdown]
# # Method 2 -  UnstructuredWordDocumentLoader

# %%
print(" UnstructuredWordDocumentLoader")

try:
   print(f"Loaded : {len(docs)} documents") 
   print(f"content preview : {docs[0].page_content[:100]}") 
   print(f"Metadata :{docs[0].metadata}")

except Exception as e:
    print(f"Error {e}")
# Out:
#  UnstructuredWordDocumentLoader
# Loaded : 1 documents
# content preview : Supervised Learning
#
# DOMAIN : Automobiles
#
# CONTEXT :
#
# There is a huge demand for used cars in the I
# Metadata :{'source': 'data/docx/ml.docx'}
